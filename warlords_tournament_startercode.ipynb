# %% [markdown]
# # Warlords Multi-Agent Toernooi
# Dit notebook draait de Warlords-omgeving vanuit de Arcade Learning Environment (ALE) met 4 custom agenten.
#
# Dit notebook is ontworpen om te draaien in Google Colab. Als je hem lokaal draait, moet je mogelijk meer libraries installeren en controleren of hun versies compatibel zijn.

# %% [markdown]
# ## 1 Installeer libraries

# %% [markdown]
# Voer eerst de onderstaande codecell uit om de libraries te installeren.

# %%
# Install the necessary libraries
# !pip install 'pettingzoo[atari]'
#!pip install "autorom[accept-rom-license]"
#!pip install --find-links dist/ --no-cache-dir AutoROM[accept-rom-license]
# Out:
# WARNING: Ignoring invalid distribution ~ransformers (/Users/mattias/anaconda3/lib/python3.11/site-packages)
# Requirement already satisfied: pettingzoo[atari] in /Users/mattias/anaconda3/lib/python3.11/site-packages (1.25.0)
# Requirement already satisfied: numpy>=1.21.0 in /Users/mattias/anaconda3/lib/python3.11/site-packages (from pettingzoo[atari]) (1.25.2)
# Requirement already satisfied: gymnasium>=1.0.0 in /Users/mattias/anaconda3/lib/python3.11/site-packages (from pettingzoo[atari]) (1.2.3)
# Collecting multi_agent_ale_py>=0.1.11 (from pettingzoo[atari])
#   Downloading multi_agent_ale_py-0.1.12-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.0 kB)
# Requirement already satisfied: pygame>=2.3.0 in /Users/mattias/anaconda3/lib/python3.11/site-packages (from pettingzoo[atari]) (2.6.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/mattias/anaconda3/lib/python3.11/site-packages (from gymnasium>=1.0.0->pettingzoo[atari]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/mattias/anaconda3/lib/python3.11/site-packages (from gymnasium>=1.0.0->pettingzoo[atari]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/mattias/anaconda3/lib/python3.11/site-packages (from gymnasium>=1.0.0->pettingzoo[atari]) (0.0.4)
# Downloading multi_agent_ale_py-0.1.12-cp311-cp311-macosx_11_0_arm64.whl (433 kB)
# WARNING: Ignoring invalid distribution ~ransformers (/Users/mattias/anaconda3/lib/python3.11/site-packages)
# Installing collected packages: multi_agent_ale_py
# WARNING: Ignoring invalid distribution ~ransformers (/Users/mattias/anaconda3/lib/python3.11/site-packages)
# Successfully installed multi_agent_ale_py-0.1.12

# %% [markdown]
# **Herstart nu je kernel**. Na het herstarten kun je direct doorgaan met de volgende codecel.

# %% [markdown]
# ## 2 Importeer libraries en download Atari ROMs

# %% [markdown]
# Je krijgt een prompt om de AutoROM-overeenkomst te accepteren. Druk op "Y" wanneer je dit ziet.

# %%
# Start AutoROM

# !AutoROM --accept-license

# Import libraries
from pettingzoo.atari import warlords_v3
from pettingzoo.utils import BaseParallelWrapper
import gymnasium as gym
import numpy as np
from collections import defaultdict, Counter
import importlib
import os
import imageio
# Out:
# AutoROM will download the Atari 2600 ROMs.
# They will be installed to:
# 	/Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms
# 	/Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms
#
# Existing ROMs will be overwritten.
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/adventure.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/adventure.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/air_raid.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/air_raid.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/alien.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/alien.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/amidar.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/amidar.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/assault.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/assault.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/asterix.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/asterix.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/asteroids.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/asteroids.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/atlantis.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/atlantis.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/atlantis2.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/atlantis2.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/backgammon.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/backgammon.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/bank_heist.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/bank_heist.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/basic_math.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/basic_math.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/battle_zone.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/battle_zone.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/beam_rider.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/beam_rider.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/berzerk.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/berzerk.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/blackjack.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/blackjack.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/bowling.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/bowling.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/boxing.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/boxing.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/breakout.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/breakout.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/carnival.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/carnival.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/casino.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/casino.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/centipede.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/centipede.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/chopper_command.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/chopper_command.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/combat.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/combat.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/crazy_climber.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/crazy_climber.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/crossbow.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/crossbow.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/darkchambers.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/darkchambers.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/defender.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/defender.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/demon_attack.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/demon_attack.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/donkey_kong.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/donkey_kong.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/double_dunk.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/double_dunk.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/earthworld.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/earthworld.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/elevator_action.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/elevator_action.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/enduro.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/enduro.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/entombed.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/entombed.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/et.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/et.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/fishing_derby.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/fishing_derby.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/flag_capture.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/flag_capture.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/freeway.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/freeway.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/frogger.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/frogger.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/frostbite.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/frostbite.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/galaxian.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/galaxian.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/gopher.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/gopher.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/gravitar.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/gravitar.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/hangman.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/hangman.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/haunted_house.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/haunted_house.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/hero.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/hero.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/human_cannonball.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/human_cannonball.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/ice_hockey.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/ice_hockey.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/jamesbond.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/jamesbond.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/journey_escape.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/journey_escape.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/joust.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/joust.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/kaboom.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/kaboom.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/kangaroo.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/kangaroo.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/keystone_kapers.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/keystone_kapers.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/king_kong.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/king_kong.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/klax.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/klax.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/koolaid.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/koolaid.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/krull.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/krull.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/kung_fu_master.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/kung_fu_master.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/laser_gates.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/laser_gates.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/lost_luggage.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/lost_luggage.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/mario_bros.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/mario_bros.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/maze_craze.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/maze_craze.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/miniature_golf.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/miniature_golf.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/montezuma_revenge.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/montezuma_revenge.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/mr_do.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/mr_do.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/ms_pacman.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/ms_pacman.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/name_this_game.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/name_this_game.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/othello.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/othello.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/pacman.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/pacman.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/phoenix.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/phoenix.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/pitfall.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/pitfall.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/pitfall2.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/pitfall2.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/pong.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/pong.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/pooyan.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/pooyan.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/private_eye.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/private_eye.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/qbert.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/qbert.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/riverraid.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/riverraid.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/road_runner.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/road_runner.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/robotank.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/robotank.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/seaquest.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/seaquest.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/sir_lancelot.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/sir_lancelot.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/skiing.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/skiing.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/solaris.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/solaris.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/space_invaders.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/space_invaders.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/space_war.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/space_war.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/star_gunner.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/star_gunner.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/superman.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/superman.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/surround.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/surround.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/tennis.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/tennis.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/tetris.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/tetris.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/tic_tac_toe_3d.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/tic_tac_toe_3d.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/time_pilot.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/time_pilot.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/trondead.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/trondead.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/turmoil.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/turmoil.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/tutankham.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/tutankham.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/up_n_down.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/up_n_down.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/venture.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/venture.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/video_checkers.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/video_checkers.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/video_chess.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/video_chess.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/video_cube.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/video_cube.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/video_pinball.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/video_pinball.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/warlords.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/warlords.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/wizard_of_wor.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/wizard_of_wor.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/word_zapper.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/word_zapper.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/yars_revenge.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/yars_revenge.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/AutoROM/roms/zaxxon.bin
# Installed /Users/mattias/anaconda3/lib/python3.11/site-packages/multi_agent_ale_py/roms/zaxxon.bin
# Done!

# %% [markdown]
# ## 3 Initialiseer agenten

# %% [markdown]
# In deze codecel importeren we de AI-agenten om Warlords te spelen. De bestanden met de agentklassen moeten zich in dezelfde map bevinden als dit notebook.

# %%
# Import the agent classes
from agent1 import Agent1
from agent2 import Agent2
from agent3 import Agent3
from agent4 import Agent4

# Instantiate each agent (pass args if needed)
agent_instances = [
    Agent1(),
    Agent2(),
    Agent3(),
    Agent4()
]

agent_names = ['Agent1', 'Agent2', 'Agent3', 'Agent4']
scores = defaultdict(int)
wins = Counter()

# %% [markdown]
# ## 4 Speel het spel

# %% [markdown]
# In deze sectie spelen de vier agenten Warlords. Aan het einde van elk spel wordt de score bijgehouden. De winnaar is de agent met de hoogste score.

# %%
# Create environment
env = warlords_v3.env(render_mode="rgb_array")

# Prepare directory for videos
video_dir = "./warlords_videos"
os.makedirs(video_dir, exist_ok=True)

# %% [markdown]
# De volgende codecel speelt het spel.

# %%
# Function to run one game and record video
def run_game(game_id):
    env.reset()

    # Map environment agents to their corresponding agent instances
    agent_mapping = {
        env.agents[i]: agent_instances[i]
        for i in range(len(env.agents))
    }

    # Map environment agents to their corresponding agent names
    agent_name_mapping = {
        env.agents[i]: agent_names[i]
        for i in range(len(env.agents))
    }

    # Reset scores
    for agent in agent_names:
        scores[agent] = 0

    done = False
    terminated = False
    truncated = False

    frames = []

    for agent in env.agent_iter():
        observation, reward, termination, truncation, info = env.last()
        scores[agent_name_mapping[agent]] += reward

        if reward > 0:
            print(f"Agent {agent_name_mapping[agent]} won the game!")
            wins[agent_name_mapping[agent]] += 1

        # Use this to debug
        # print(f"Agent: {agent}, Name: {agent_name_mapping[agent]}, Reward: {reward}, Termination: {termination}, Truncation: {truncation}")

        if termination or truncation:
            action = None
        else:
            # this is where you would insert your policy
            agent_obj = agent_mapping[agent]
            action = agent_obj.act(observation)

        env.step(action)

        # Capture the rendered frame
        frame = env.render()
        frames.append(frame)
    env.close()

    # Save video using imageio
    video_path = os.path.join(video_dir, f"game_{game_id}.mp4")
    imageio.mimsave(video_path, frames, fps=15)

# %%
# Run 10 games
for game in range(10):
    print(f"Running game {game + 1}...")
    run_game(game_id=game)

print("\nFinal Scores:")
for agent in agent_names:
    print(f"{agent}: Total Reward = {scores[agent]}, Wins = {wins[agent]}")

try:
    winner = wins.most_common(1)[0]
    print(f"Winner: {winner[0]} with {winner[1]} wins!")
except IndexError:
    print("No winners found.")

# %%
# Display download links for videos
import glob
from IPython.display import FileLink, display
video_files = sorted(glob.glob(f"{video_dir}/*.mp4"))
print("\nDownload the recorded games:")
for file in video_files:
    display(FileLink(file))
